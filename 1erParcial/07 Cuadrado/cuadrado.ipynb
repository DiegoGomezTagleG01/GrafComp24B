# %% [markdown]
# # Universidad Autónoma del Estado de México
#
# # Centro Universitario UAEM Zumpango
#
# ## Ingenieria en computación
#
# ## Graficación Computacional
#
# **Alumno:** Diego Gómez Tagle González
#
# **Profesor:** Hazem Alvarez
#
# **Fecha:** 25 de Septiembre de 2024
#
# **Descripción:** Graficacion de los vectores vistos en clase

# %% [markdown]
# ## 1 Triangulo

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1],[1])

# %%
plt.plot([1,1.5,2],[1,2,1])

# %% [markdown]
# Complete el triangulo para que la figura sea un triangulo completo

# %%
plt.plot([1,1.5,2,1],[1,2,1,1])

# %% [markdown]
# ## Cuadrado

# %% [markdown]
# Empleando .plot dibuja un cuadrado

# %%
plt.plot([1,1,2,2,1],[1,2,2,1,1])

# %%
plt.plot([0,1,1,0],[0,1,1,0])

# %%
plt.plot([1,1,2,2,1],[1,2,2,1,1])
plt.plot([1,1.5,2,1],[1,2,1,1])
