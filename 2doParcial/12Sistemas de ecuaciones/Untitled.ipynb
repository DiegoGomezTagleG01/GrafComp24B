# %% [markdown]
# <img src="https://iieg.gob.mx/strategos/wp-content/uploads/2016/08/logo1.png" alt="Logo" width="300" height="150" align="center"/>
# ---
#
# # Universidad Autónoma del Estado de México
# ### Centro Universitario UAEM Zumpango
# ---
#
# ## Ingeniería en Computación
# ### Ciencia de Datos
# ---
# ### Proyecto de Minería dSistemas de ecuaciones linealesum, AMLO (4T)**
#
# ---
#
#   Matrícula: 2125695
#
# - **Gómez Tagle González Diego**
#   Matrícula: 2125Hazem Alvarez Rodriguezfesor:** Dr. Asdrúbal López Chau
#
# **Fecha:** ** de noviembre del 2024
#
# ---

# %% [markdown]
# # SISTEMAS DE ECUACIONES LINEALES

# %% [markdown]
# Dentro de python se nos permite solucionar sistemas de ecuaciones por medio de la libreria numpy

# %%
import numpy as np

A = np.matrix([[2, 3],[1, -2]])
b = np.matrix([[8],[-10]])

print("Esta es la matriz A",A)
print("Esta es la matriz B",b)
# Out:
# Esta es la matriz A [[ 2  3]
#  [ 1 -2]]
# Esta es la matriz B [[  8]
#  [-10]]

# %% [markdown]
# Un sistema de
#  n ecuaciones co
# n incógnitas se puede escribir de la siguiente forma:

# %% [markdown]
# ![image.png](attachment:7aee4521-2bf4-44bf-a2ec-87c8dbedd2e0.png)

# %% [markdown]
# El sistema también se puede escribir en forma matricial de la forma:
#
# ![image.png](attachment:15384ebc-2ff8-4876-a46d-c9fc1569ae00.png)

# %% [markdown]
# ![image.png](attachment:e0ec378f-0f9d-4bd4-8746-fce81ea32ea6.png)![image.png](attachment:ed968fe7-7f09-4f00-ac40-f1c372417e1e.png)

# %%
A = np.matrix([[2, 3],[1, -2]])
b = np.matrix([[8],[-10]])

print("Esta es la matriz A",A)
print("Esta es la matriz B",b)
# Out:
# Esta es la matriz A [[ 2  3]
#  [ 1 -2]]
# Esta es la matriz B [[  8]
#  [-10]]

# %%
x = (A**-1)*b
print("matriz inversa",x)
# Out:
# matriz inversa [[-2.]
#  [ 4.]]

# %%
if np.linalg.det(A) == 0:
    x = None
    print("No se puede resolver")
else:
    x = (A**-1)*b

# %% [markdown]
# ## Determinante
#
# Un determinante es un número que puede calcularse sobre las matrices cuadradas. Su valor viene dado por la suma de los productos de las diagonales de la matriz en una dirección menos la suma de los productos de las diagonales en la otra dirección. Se representa con el símbolo |A|.

# %% [markdown]
# ![image.png](attachment:b422133d-059a-45a6-aa48-6562e1f8b1a1.png)

# %%
A = np.array ([[9]])
print (A.shape)

print (np.linalg.det (A))
# Out:
# (1, 1)
# 9.000000000000002

# %% [markdown]
# ![image.png](attachment:620eac05-7a17-4975-84c0-b304f1ea94f2.png)

# %% [markdown]
# ![image.png](attachment:2bc62ece-40ab-4f43-81b7-13bfd3adf3ac.png)![image.png](attachment:fbace2b3-456f-4cc7-81b6-55657e55002d.png)

# %%
A = np.matrix([[3, 2, -1],[2, -2, +4],[-1,1/2,-1]])
b = np.matrix([[1],[-2],[0]])
x = (A**-1)*b
print("matriz inversa",x)

print("Determinante de A,",np.linalg.det(A))
# Out:
# matriz inversa [[ 1.]
#  [-2.]
#  [-2.]]
# Determinante de A, -3.000000000000001

# %% [markdown]
# ![image.png](attachment:c070c9fa-5fa7-4ad2-8179-e6920f419f2d.png)

# %% [markdown]
# ![image.png](attachment:9aef5e9b-ae78-4aa6-aa5e-0629b71e9ab6.png)

# %% [markdown]
# ## Ejercicio 1

# %%
A = np.matrix([[4, -1],[-2, 0]])

print("matriz A",A)

print("Determinante de A,",np.linalg.det(A))
# Out:
# matriz A [[ 4 -1]
#  [-2  0]]
# Determinante de A, -2.0

# %% [markdown]
# ## Ejercicio 2

# %%
A = np.matrix([[5, 0, 2],[3, 1, 1],[0,1,2]])
print("matriz A",A)

print("Determinante de A,",np.linalg.det(A))
# Out:
# matriz A [[5 0 2]
#  [3 1 1]
#  [0 1 2]]
# Determinante de A, 11.000000000000002

# %% [markdown]
# ## Ejercicio 3

# %%
A = np.matrix([[3, 2, -1],[2, -2, +4],[-1,1/2,-1]])
b = np.matrix([[1],[-2],[0]])
x = (A**-1)*b
print("matriz inversa",x)

print("Determinante de A,",np.linalg.det(A))
# Out:
# matriz inversa [[ 1.]
#  [-2.]
#  [-2.]]
# Determinante de A, -3.000000000000001
