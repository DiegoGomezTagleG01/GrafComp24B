# %% [markdown]
# # Universidad Autónoma del Estado de México
#
# # Centro Universitario UAEM Zumpango
#
# ## Ingenieria en computación
#
# ## Graficación Computacional
#
# **Alumno:** Diego Gómez Tagle González
#
# **Profesor:** Hazem Alvarez
#
# **Fecha:** 30 de Septiembre de 2024
#
# **Descripción:** Examen 2

# %% [markdown]
# ## examen 2

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([-8,0.5],[8,4]) #1
plt.plot([0.5,-1],[4,-3]) #2

plt.plot([-1,-5],[-3,-13]) #3
plt.plot([-9,-5],[-15,-13],color='black') # Triangulo
plt.plot([-6.5,-1],[-8,-3],color='black')# triangulo

plt.plot([-5,-1],[-13,-20]) #4
plt.plot([-5,-14],[-13,-22],color='black') # Triangulo
plt.plot([-5,-1],[-13,-3],color='black') # Triangulo

plt.plot([-1,8],[-20,-8]) # 5
plt.plot([-1,2],[-20,-30],color='black') # Triangulo
plt.plot([-1,6],[-20,-20],color='black') # Triangulo
plt.plot([6,8],[-20,-8],color='black') # Triangulo
plt.plot([8,14],[-8,-15],color='black') # Triangulo


plt.plot([8,7.8],[-8,-3]) #6
plt.plot([7.8,14],[-3,-15]) #7
plt.plot([14,6],[-15,-20]) #8
plt.plot([6,2],[-20,-30]) #9

plt.plot([2,-7],[-30,-32]) #10 

plt.plot([-7,-14],[-32,-22]) #11
plt.plot([-14,-1],[-22,-3],color='black') # Triangulo
plt.plot([-7,-5],[-32,-13],color='black') # Triangulo
plt.plot([-7,-1],[-32,-20],color='black') # Triangulo

plt.plot([-1,-1],[-20,-20],color='black') # Triangulo


plt.plot([-14,-13],[-22,-6]) #12
plt.plot([-14,-1],[-22,-3],color='black') # Triangulo


plt.plot([-13,-9],[-6,-15]) #13
plt.plot([-9,-1],[-15,-3],color='black') # Triangulo


plt.plot([-9,-1],[-15,-3],color='black') # Triangulo

plt.plot([-9,-6.5],[-15,-8]) #14
plt.plot([-10,0.5],[-2,4],color='black') #Triangulo

plt.plot([-6.5,-10],[-8,-2]) #15
plt.plot([-6.5,0.5],[-8,4],color='black')# triangulo

plt.plot([-10,-8],[-2,8])

# %% [markdown]
# ![image.png](attachment:f374cd30-7371-4fd5-be6c-69bc07cc1714.png)

# %% [markdown]
# Se cuentan 16 vertices, aplicando la formula n-2 donde n es el numero de vertices de la figura, entonces resulta en que debe tener 14 triangulos

# %% [markdown]
# ## Coloreando la figura

# %%
plt.plot([-8,0.5],[8,4]) #1
plt.plot([0.5,-1],[4,-3]) #2

plt.plot([-1,-5],[-3,-13]) #3
plt.plot([-9,-5],[-15,-13],color='black') # Triangulo
plt.plot([-6.5,-1],[-8,-3],color='black')# triangulo
## rellenar figura
plt.fill([-8, 0.5,-10], [8, 4, -2], alpha=0.2)

plt.plot([-5,-1],[-13,-20]) #4
plt.plot([-5,-14],[-13,-22],color='black') # Triangulo
## rellenar figura
plt.fill([-5, -7,-14], [-13, -32, -22], alpha=0.2)
plt.plot([-5,-1],[-13,-3],color='black') # Triangulo

plt.plot([-1,8],[-20,-8]) # 5
plt.plot([-1,2],[-20,-30],color='black') # Triangulo
plt.plot([-1,6],[-20,-20],color='black') # Triangulo
plt.plot([6,8],[-20,-8],color='black') # Triangulo
plt.plot([8,14],[-8,-15],color='black') # Triangulo


plt.plot([8,7.8],[-8,-3]) #6
plt.plot([7.8,14],[-3,-15]) #7
plt.plot([14,6],[-15,-20]) #8
plt.plot([6,2],[-20,-30]) #9

plt.plot([2,-7],[-30,-32]) #10 

plt.plot([-7,-14],[-32,-22]) #11
plt.plot([-14,-1],[-22,-3],color='black') # Triangulo
plt.plot([-7,-5],[-32,-13],color='black') # Triangulo
plt.plot([-7,-1],[-32,-20],color='black') # Triangulo

plt.plot([-1,-1],[-20,-20],color='black') # Triangulo


plt.plot([-14,-13],[-22,-6]) #12
plt.plot([-14,-1],[-22,-3],color='black') # Triangulo
## rellenar figura
plt.fill([-14, 13,-14], [-22, -6, -22], alpha=0.2)


plt.plot([-13,-9],[-6,-15]) #13
plt.plot([-9,-1],[-15,-3],color='black') # Triangulo
## rellenar figura
plt.fill([-13, -9,-14], [-6, -15, -22], alpha=0.2)


plt.plot([-9,-1],[-15,-3],color='black') # Triangulo

plt.plot([-9,-6.5],[-15,-8]) #14
plt.plot([-10,0.5],[-2,4],color='black') #Triangulo

plt.plot([-6.5,-10],[-8,-2]) #15
plt.plot([-6.5,0.5],[-8,4],color='black')# triangulo
## rellenar figura
plt.fill([-6.5, -10,0.5], [-8, -2, 4], alpha=0.2)



## rellenar figura
plt.fill([0.5, -1,-6.5], [4, -3, -8], alpha=0.2)

## rellenar figura
plt.fill([-14, -9,-5], [-22, -15, -13], alpha=0.2)


## rellenar figura
plt.fill([-9, -6.5,-1], [-15, -8, -3], alpha=0.2)

## rellenar figura
plt.fill([-9, -5,-1], [-15, -13, -3], alpha=0.2)


## rellenar figura
plt.fill([-5, -7,-1], [-13, -32, -20], alpha=0.2)

## rellenar figura
plt.fill([2, -7,-1], [-30, -32, -20], alpha=0.2)

## rellenar figura
plt.fill([2, 6,-1], [-30, -20, -20], alpha=0.2)

## rellenar figura
plt.fill([8, 6,-1], [-8, -20, -20], alpha=0.2)

## rellenar figura
plt.fill([8, 6,14], [-8, -20, -15], alpha=0.2)

## rellenar figura
plt.fill([8, 7.8,14], [-8, -3, -15], alpha=0.2)


plt.plot([-10,-8],[-2,8]) #
